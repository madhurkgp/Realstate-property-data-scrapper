# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'}
r = requests.get("https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/",headers=headers )
content = r.content

# %%
soup = BeautifulSoup(content,"html.parser")
# soup

# %%
# lotsizes=[]
# propertyFeatures = soup.find_all("div",{'class':'columnGroup'})
# for i in propertyFeatures:
    
#     for featureGroup,featureName in zip(i.find_all("span",{'class':'featureGroup'}),i.find_all("span",{'class':'featureName'})):
# #         print(featureGroup,featureName)
#         if 'Lot Size' in featureGroup.text:
#             print(featureName.text)
#         else:
#             print('None')
# #             d['Lot Size'] = featureName.text

# %%
l = []
details = soup.find_all("div",{'class':'details'})
bedandbaths = []
for i in details:
    bedandbaths.append(i.text.split('\n')[2])
propAddress = soup.find_all("div",{'class':'propAddress'})
price = soup.find_all("div",{'class':'price'})
details = soup.find_all("div",{'class':'details'})
secondaryDetails = soup.find_all("div",{'class':'secondaryDetails'})

for i in range(len(propAddress)):
    d={}
    try:
        d['Address'] = (propAddress[i].text.split(',',1)[0])
    except:
        d['Address'] = None
    
    try:
        d['Locality'] = (propAddress[i].text.split(',',1)[1])
    except:
        d['Locality'] = None
    
    try:
        d['Price'] = (price[i].text.strip())
    except:
        d['Price'] = None
        
    try:
        var = bedandbaths[i]
        var = var.split('|')
        
        if len(var) == 1:
            d['Beds'] = None
            d['Full Baths'] = None
            d['Half Baths'] = None
        elif len(var) == 2:
            d['Beds'] = var[0]
            d['Full Baths'] = var[1]
            d['Half Baths'] = None
        else:
            d['Beds'] = var[0]
            d['Full Baths'] = var[1]
            d['Half Baths'] = var[2]
    except:
        d['Beds'] = None
        d['Full Baths'] = None
        d['Half Baths'] = None
    
    try:
        area = secondaryDetails[i].text.strip().split('\n')[1]
        if area == "":
            d['Area'] = None
        else:
            d['Area'] = area
    except:
        d['Area'] = None
    
    try:
        area = secondaryDetails[i].text.strip().split('\n')[1]
        if area == "":
            d['Area'] = None
        else:
            d['Area'] = area
    except:
        d['Area'] = None
        

            

    l.append(d)

# %%
base_url = 'https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s='
base_url+'20'+'.html'
# Out:
# 'https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html'

# %%
df = pd.DataFrame(l)
df
# Out:
#                  Address          Area     Beds      Full Baths    Half Baths  \
# 0              0 Gateway          None     None            None          None
# 1  1003 Winchester Blvd.          None  4 Beds     4 Full Baths          None
# 2          600 Talladega  3,154 Sq. Ft  5 Beds     3 Full Baths          None
# 3     3239 Spearhead Way  3,076 Sq. Ft  4 Beds    3 Full Baths    1 Half Bath
# 4     522 Emerald Street  1,172 Sq. Ft  3 Beds     3 Full Baths          None
# 5   1302 Veteran's Drive  1,932 Sq. Ft  4 Beds     2 Full Baths          None
# 6       1021 Cypress Cir  1,676 Sq. Ft  4 Beds     3 Full Baths          None
# 7         913 Madison Dr  1,344 Sq. Ft  3 Beds     2 Full Baths          None
# 8      1344 Teton Street  1,920 Sq. Ft  3 Beds     2 Full Baths          None
# 9         4 Minnies Lane  1,664 Sq. Ft  3 Beds     2 Full Baths          None
#
#                   Locality     Price
# 0   Rock Springs, WY 82901  $725,000
# ...

# %%
l = []
for i in range(0,30,10):
    r = requests.get("https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="+str(i)+'.html',headers=headers )
    content = r.content
    soup = BeautifulSoup(content,"html.parser")
    details = soup.find_all("div",{'class':'details'})
    bedandbaths = []
    for i in details:
        bedandbaths.append(i.text.split('\n')[2])
    propAddress = soup.find_all("div",{'class':'propAddress'})
    price = soup.find_all("div",{'class':'price'})
    details = soup.find_all("div",{'class':'details'})
    secondaryDetails = soup.find_all("div",{'class':'secondaryDetails'})

    for i in range(len(propAddress)):
        d={}
        try:
            d['Address'] = (propAddress[i].text.split(',',1)[0])
        except:
            d['Address'] = None

        try:
            d['Locality'] = (propAddress[i].text.split(',',1)[1])
        except:
            d['Locality'] = None

        try:
            d['Price'] = (price[i].text.strip())
        except:
            d['Price'] = None

        try:
            var = bedandbaths[i]
            var = var.split('|')

            if len(var) == 1:
                d['Beds'] = None
                d['Full Baths'] = None
                d['Half Baths'] = None
            elif len(var) == 2:
                d['Beds'] = var[0]
                d['Full Baths'] = var[1]
                d['Half Baths'] = None
            else:
                d['Beds'] = var[0]
                d['Full Baths'] = var[1]
                d['Half Baths'] = var[2]
        except:
            d['Beds'] = None
            d['Full Baths'] = None
            d['Half Baths'] = None

        try:
            area = secondaryDetails[i].text.strip().split('\n')[1]
            if area == "":
                d['Area'] = None
            else:
                d['Area'] = area
        except:
            d['Area'] = None

        try:
            area = secondaryDetails[i].text.strip().split('\n')[1]
            if area == "":
                d['Area'] = None
            else:
                d['Area'] = area
        except:
            d['Area'] = None

        l.append(d)

df = pd.DataFrame(l)
df
# Out:
#                           Address          Area     Beds      Full Baths  \
# 0                       0 Gateway          None     None            None
# 1           1003 Winchester Blvd.          None  4 Beds     4 Full Baths
# 2                   600 Talladega  3,154 Sq. Ft  5 Beds     3 Full Baths
# 3              3239 Spearhead Way  3,076 Sq. Ft  4 Beds    3 Full Baths
# 4              522 Emerald Street  1,172 Sq. Ft  3 Beds     3 Full Baths
# 5            1302 Veteran's Drive  1,932 Sq. Ft  4 Beds     2 Full Baths
# 6                1021 Cypress Cir  1,676 Sq. Ft  4 Beds     3 Full Baths
# 7                  913 Madison Dr  1,344 Sq. Ft  3 Beds     2 Full Baths
# 8               1344 Teton Street  1,920 Sq. Ft  3 Beds     2 Full Baths
# 9                  4 Minnies Lane  1,664 Sq. Ft  3 Beds     2 Full Baths
# 10                  9339 Sd 26900          None     None            None
# 11               RR674P13 Hwy 377          None     None            None
# ...
